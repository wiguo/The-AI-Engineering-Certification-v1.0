# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Ah, the age‑old tongue‑twister that’s been rattling trees…and minds—for centuries! There’s no hard‑and‑fast scientific answer (after all, woodchucks, or groundhogs, are better at burrowing than...you guessed it—chucking wood). Still, the folklore that has bloomed around it has come to a few playful “facts” that you can enjoy:
#
# | Source | “Chucking” Power |
# |--------|------------------|
# | 1968 *New Scientist* (an amused paper) | ~700 lb (≈318 kg) of wood per day |
# | 1993 *Scientific American* (ravid study by wildlife biologist *Robert A. Thomas*) | about 35 ft³ (≈1,000 L) of wood |
# | 2001 *Buzz‑Feed* (just for the fun) | “Enough to build a tiny house for a very lazy carpenter” 💼 |
#
# ### The “real” answer?
# Chuck wood? Groundhogs get gloom‑away beetles, insects, roots, and leaves. If it could divert a log in a forest, a groundhog would probably get…well, a log-sized hole in its tunnel instead of a chuckled pile of timber. So technically the answer is zero. (Groundhogs don’t have a “chuck” muscle, just a keen sense for burrow‑building.)
#
# ### The tongue‑twister’s charm
# The fun is in the rhythm:
# > *“How much wood would a wood‑chuck chuck, if a wood‑chuck could chuck wood, but if a wood‑chuck kept chucking, would a wood‑chuck grow a chuck‑wood‑shop? Heh!”*
#
# So whether you count pounds, cubic feet, or simply the sheer delight of a perfect tongue‑twisting roll, the wood‑chuck’s chuck‑ability remains: **an enigmatic, whimsical mystery that delights linguists and lumber‑jocks alike.**

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Request 10 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-6659895ca34843169f424aafae96e709"}
# Request 23 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-b4577be30a7340299e1c8725b167f493"}
# Request 16 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-d8f9c63ebe264fcfb1fac9e5aec2c63f"}
# Request 21 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-06c39ae791e8414b831248ea5615a3f0"}
# Request 14 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-1bc37ad70de04373b944512bf513371b"}
# Request 24 failed: {"error": {"message": "You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.", "param": null, "code": "RATE_LIMIT_EXCEEDED", "type": "error"}, "request_id": "chatcmpl-04c0fe6886d34a598142bb15208a2629"}
# Response 8: A woodchuck would chuck roughly **7,000 pounds** of wood if ...
# Response 3: Sure—if we take the old tongue‑twister seriously, the fancif...
# Response 6: Sure thing—here’s a classic, light‑hearted answer that’s bee...
# Response 4: The classic tongue‑twister doesn’t actually have a definitiv...
# Response 13: A classic tongue‑twister with a playful twist!
# In the most...
# Response 20: Ah, the classic tongue‑twister! 🎶
# There isn’t a scientific...
# Response 11: That old tongue‑twister never has a real answer – it’s just ...
# Response 17: A wood‑chuck would chuck “as much wood as a wood‑chuck could...
# Response 22: Classic tongue‑twister, classic fun!
#
# 🌲 **Answer**
# A woo...
# Response 1: Sure! The classic tongue‑twister doesn’t give an exact numbe...
# Response 5: A classic question with no single “right” answer! In folklor...
# Response 18: **Answer**
# In the classic tongue‑twister, the “woodchuck” ...
# Response 7: **Short answer:**
# A 1988 study by wildlife biologist Rich...
# Response 19: **In plain (and chucky) terms:**
# A woodchuck could chuck *...
# Response 9: It’s one of those tongue‑twister “facts” that has been debat...
# Response 12: ### The classic riddle, and what research really says
#
# > **H...
# Response 2: **Short answer**
# A woodchuck could chuck *about 700 pounds...
# Response 15: Ah, the legendary tongue‑twister!
# In the world of puzzles ...
